# %%
#Q2
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

driver.get("http://www.bcci.tv/")

# %%
search=driver.find_element(By.XPATH, "/html/body/nav/div[1]/div[2]/ul[1]/li[2]")
search.click()

# %%
try:
    match=driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]')
    matcht=[]
    for i in match:
        matcht.append(i.text)
except NoSuchElementException:
    matcht.append('-')
try:
    series=driver.find_elements(By.XPATH,'//h5[@class="match-tournament-name ng-binding"]')
    seriest=[]
    for i in series:
        seriest.append(i.text)
except NoSuchElementException:
    seriest.append('-')
try:
    place=driver.find_elements(By.XPATH,'//span[@class="ng-binding ng-scope"]')
    placet=[]
    for i in place:
        placet.append(i.text)
except NoSuchElementException:
    placet.append('-')
    
try:
    time=driver.find_elements(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')
    timet=[]
    for i in time:
        timet.append(i.text)
except NoSuchElementException:
    timet.append('-')

# %%
df=pd.DataFrame({
    'Match title':matcht,'Series':seriest,'Place':placet,'Time':timet
})
df
# Out:
#   Match title                           Series  \
# 0  2nd T20I -       INDIA TOUR OF IRELAND 2023
# 1  3rd T20I -       INDIA TOUR OF IRELAND 2023
# 2   1st ODI -                    ASIA CUP 2023
# 3   2nd ODI -                    ASIA CUP 2023
# 4   1st ODI -  AUSTRALIA TOUR OF INDIA 2023-24
# 5   2nd ODI -  AUSTRALIA TOUR OF INDIA 2023-24
# 6   3rd ODI -  AUSTRALIA TOUR OF INDIA 2023-24
# 7   1st ODI -          ICC MENS WORLD CUP 2023
#
#                                            Place          Time
# 0                                   The Village,   7:30 PM IST
# 1                                   The Village,   7:30 PM IST
# 2       Pallekele International Cricket Stadium,  10:00 AM IST
# 3       Pallekele International Cricket Stadium,  10:00 AM IST
# 4  Punjab Cricket Association IS Bindra Stadium,   1:30 PM IST
# 5                        Holkar Cricket Stadium,   1:30 PM IST
# 6        Saurashtra Cricket Association Stadium,   1:30 PM IST
# ...

# %%
#Q3
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

driver.get("http://statisticstimes.com/")

# %%
search=driver.find_element(By.XPATH, "/html/body/div[2]/div[1]/div[2]/div[2]/button")
search.click()
search=driver.find_element(By.XPATH, "/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]")
search.click()
search=driver.find_element(By.XPATH, "/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
search.click()

# %%
rankt=[]
statet= []
GSDP8t=[]
GSDP9t=[]
sharet=[]
GDPt=[]

# %%
try:
    rank = driver.find_elements(By.XPATH,'//td[@class="data1"]')
    for i in rank[0:33]:
        rankt.append(i.text)
except NoSuchElementException:
    rankt.append('-')
try:
    state = driver.find_elements(By.XPATH,'//td[@class="name"]')
    for i in state[0:33]:
        statet.append(i.text)
except NoSuchElementException:
    statet.append('-')        
try:
    GSDP8 = driver.find_elements(By.XPATH,'//td[@class="data sorting_1"]')
    for i in GSDP8[0:33]:
        GSDP8t.append(i.text)
except NoSuchElementException:
    GSDP8t.append('-')
try:
    GSDP9 = driver.find_elements(By.XPATH,'//tr[@class="odd"]/td[3]')
    for i in GSDP9[0:33]:
        GSDP9t.append(i.text)
except NoSuchElementException:
    GSDP9t.append('-')
try:
    share = driver.find_elements(By.XPATH,'//tr[@class="odd"]/td[5]')
    for i in share[0:33]:
        sharet.append(i.text)
except NoSuchElementException:
    sharet.append('-')
try:
    GDP = driver.find_elements(By.XPATH,'//tr[@class="odd"]/td[6]')
    for i in GDP[0:33]:
        GDPt.append(i.text)
except NoSuchElementException:
    GDPt.append('-')

# %%
df=pd.DataFrame({
    'Rank':rankt,'State':statet,'GSDP 18-19':GSDP8t,'GSDP 19-20':GSDP9t,'Share 18-19':sharet,'GDP 2019':GDPt
})
df
# Out:
#    Rank                      State GSDP 18-19 GSDP 19-20 Share 18-19  \
# 0     1                Maharashtra  2,632,792          -      13.94%
# 1     2                 Tamil Nadu  1,630,208  1,687,818       8.39%
# 2     3              Uttar Pradesh  1,584,764  1,631,977       7.91%
# 3     4                    Gujarat  1,502,899  1,020,989       4.99%
# 4     5                  Karnataka  1,493,127    969,604       4.56%
# 5     6                West Bengal  1,089,898          -       4.14%
# 6     7                  Rajasthan    942,586    831,610       3.89%
# 7     8             Andhra Pradesh    862,957    574,760       2.79%
# 8     9                  Telangana    861,031          -       1.67%
# 9    10             Madhya Pradesh    809,592    328,598       1.57%
# 10   11                     Kerala    781,653          -       0.83%
# 11   12                      Delhi    774,870     80,449       0.39%
# 12   13                    Haryana    734,163          -       0.22%
# ...

# %%
#Q4
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

driver.get("https://github.com/")

# %%
search=driver.find_element(By.XPATH, "/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button")
search.click()
search=driver.find_element(By.XPATH, "/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a")
search.click()

# %%
repot=[]
repodt=[]
contrt=[] 
langt=[]

# %%
try:
    repo = driver.find_elements(By.XPATH,'//h2[@class="h3 lh-condensed"]/a')
    for i in repo:
        repot.append(i.text)
except NoSuchElementException:
    repot.append('-')
try:
    repod = driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
    for i in repod:
        repodt.append(i.text)
except NoSuchElementException:
    repodt.append('-')
try:
    lang = driver.find_elements(By.XPATH,'//span[@class="d-inline-block ml-0 mr-3"]/span[2]')
    for i in lang:
        langt.append(i.text)
except NoSuchElementException:
    langt.append('-')
try:
    contr = driver.find_elements(By.XPATH,'//div[@class="f6 color-fg-muted mt-2"]/span[2]')
    for i in contr:
        contrt.append(i.text)
except NoSuchElementException:
    contrt.append('-')

# %%
df=pd.DataFrame({'Repositery':repot, 'Repo Disc':repod,'language':langt, 'Contributors':contrt})
df

# %%
#Q7
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

driver.get("http://www.imdb.com/list/ls095964455/")

# %%
namet=[] 
yearst=[]
genret=[]
runt=[] 
rtingt=[] 
votest=[]

# %%
try:
    name = driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/a')
    for i in name:
        namet.append(i.text)
except NoSuchElementException:
    namet.append('-')
try:
    years = driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/span[2]')
    for i in years:
        yearst.append(i.text)
except NoSuchElementException:
    yearst.append('-')
try:
    genre = driver.find_elements(By.XPATH,'//span[@class="genre"]')
    for i in genre:
        genret.append(i.text)
except NoSuchElementException:
    genret.append('-')
try:
    run = driver.find_elements(By.XPATH,'//p[@class="text-muted text-small"]/span[3]')
    for i in run:
        runt.append(i.text)
except NoSuchElementException:
    runt.append('-')
try:
    rating = driver.find_elements(By.XPATH,'//div[@class="ipl-rating-widget"]/div/span[2]')
    for i in rating:
        rtingt.append(i.text)
except NoSuchElementException:
    rtingt.append('-')
try:
    votes = driver.find_elements(By.XPATH,'//p[@class="text-muted text-small"][3]/span[2]')
    for i in votes:
        votest.append(i.text)
except NoSuchElementException:
    votest.append('-')

# %%
print(len(namet),len(yearst),len(genret),len(runt),len(rtingt),len(votest))
# Out:
# 100 100 100 100 100 100

# %%
df=pd.DataFrame({'Name':namet,'Year Span':yearst,'Genre':genret,'Run Time':runt,'Ratings':rtingt,'Votes':votest})
df
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things  (2016–2024)    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  2,194,121
# ...

# %%
#Q8
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

driver.get("https://archive.ics.uci.edu/")

# %%
search=driver.find_element(By.XPATH, "/html/body/div/div[1]/div[1]/main/div/div[1]/div/div/div/a[1]")
search.click()

# %%
datant=[]
datat=[]
taskt=[]
attrt=[] 
inst=[]
nattrt=[]
yeart=[]

# %%
try:
    datan = driver.find_elements(By.XPATH,'//a[@class="link-hover link text-xl font-semibold"]')
    for i in datan:
        datant.append(i.text)
except NoSuchElementException:
    datant.append('-')
try:
    type = driver.find_elements(By.XPATH,'//div[@class="col-span-3 flex items-center gap-2"][3]/span')
    for i in type:
        datat.append(i.text)
except NoSuchElementException:
    datat.append('-')

# %%
print(len(datant),len(datat))
# Out:
# 10 9

# %%
df=pd.DataFrame({'Data Name':datant})
df
# Out:
#                               Data Name
# 0                                  Iris
# 1                         Heart Disease
# 2                                 Adult
# 3                      Dry Bean Dataset
# 4                              Diabetes
# 5                                  Wine
# 6  Breast Cancer Wisconsin (Diagnostic)
# 7                        Car Evaluation
# 8            Rice (Cammeo and Osmancik)
# 9                              Mushroom

# %%
#Q5
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

driver.get("https://www.billboard.com/")

# %%
search=driver.find_element(By.XPATH, "/html/body/div[3]/div[9]/div/div/div/ul/li[1]/h3")
search.click()
search=driver.find_element(By.XPATH, "/html/body/div[3]/div[9]/div/div/div/ul/li[1]/ul/li[2]")
search.click()

# %%
songt=[]
artit=[]
larat=[] 
perant=[] 
webot=[]

# %%
try:
    name = driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li/h3')
    for i in name:
        songt.append(i.text)
except NoSuchElementException:
    songt.append('-')
try:
    rank = driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li[4]/span')
    for i in rank:
        larat.append(i.text)
except NoSuchElementException:
    larat.append('-')
try:
    peak = driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li[5]/span')
    for i in peak:
        perant.append(i.text)
except NoSuchElementException:
    perant.append('-')
try:
    weeks = driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li[6]/span')
    for i in weeks:
        webot.append(i.text)
except NoSuchElementException:
    webot.append('-')

# %%
print(len(songt),len(larat))
# Out:
# 100 100

# %%
df=pd.DataFrame({'Song Name':songt, 'Last week rank':larat,'Peak Rank':perant,'Weeks on board':webot})
df
# Out:
#                        Song Name Last week rank Peak Rank Weeks on board
# 0                     Last Night              1         1             28
# 1                       Fast Car              2         2             20
# 2                   Cruel Summer              4         3             14
# 3                      Calm Down              6         3             49
# 4                       Fukumean              7         4              8
# ..                           ...            ...       ...            ...
# 95                       Lagunas              -        77              6
# 96                     Overdrive             68        47              3
# 97  Bzrp Music Sessions, Vol. 55             99        31             10
# 98                         Dawns              -        42             15
# 99                       Rubicon              -        63              6
#
# [100 rows x 4 columns]

# %%
#Q1
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
rankt=[] 
namet=[] 
artist=[] 
updatet=[] 
viewt=[]

# %%
try:
    rank = driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td')
    for i in rank:
        rankt.append(i.text)
except NoSuchElementException:
    rankt.append('-')

# %%
print(len(rankt))
# Out:
# 380

# %%
#Q6
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-You")
